# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
uploaded = files.upload()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-21dc3c638f66> in <module>
# ----> 1 from google.colab import files
#       2 uploaded = files.upload()
#
# ModuleNotFoundError: No module named 'google'

# %%
customers = pd.read_csv('Ecommerce Customers.csv')

# %%
customers.head()
# Out:
#                            Email  \
# 0      mstephenson@fernandez.com
# 1              hduke@hotmail.com
# 2               pallen@yahoo.com
# 3        riverarebecca@gmail.com
# 4  mstephens@davidson-herman.com
#
#                                              Address            Avatar  \
# 0       835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1     4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2  24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3   1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4  14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
#
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# ...

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
# Email                   500 non-null object
# Address                 500 non-null object
# Avatar                  500 non-null object
# Avg. Session Length     500 non-null float64
# Time on App             500 non-null float64
# Time on Website         500 non-null float64
# Length of Membership    500 non-null float64
# Yearly Amount Spent     500 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
sns.jointplot(data=customers,x='Time on Website',y='Yearly Amount Spent')

# %%
sns.jointplot(data=customers,x='Length of Membership',y='Avatar')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-8eda2473a16d> in <module>
# ----> 1 sns.jointplot(data=customers,x='Length of Membership',y='Avatar')
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2292         marginal_kws.setdefault("kde", False)
#    2293         marginal_kws.setdefault("color", color)
# -> 2294         grid.plot_marginals(distplot, **marginal_kws)
#    2295
#    2296     elif kind.startswith("hex"):
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1811         kwargs["vertical"] = True
#    1812         plt.sca(self.ax_marg_y)
# -> 1813         func(self.y, **kwargs)
#    1814
#    1815         return self
#
# ...

# %%
sns.jointplot(data=customers,x='Length of Membership',y='Yearly Amount Spent')

# %%
sns.jointplot(x='Time on App',y='Length of Membership',kind='hex',data=customers)

# %%
sns.pairplot(customers)

# %%
sns.lmplot(x='Length of Membership',y='Yearly Amount Spent',data=customers)

# %%
sns.lmplot(x='Avg. Session Length',y='Yearly Amount Spent',data=customers)

# %%
sns.lmplot(x='Avg. Session Length',y='Time on Website',data=customers)

# %%
customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
# Email                   500 non-null object
# Address                 500 non-null object
# Avatar                  500 non-null object
# Avg. Session Length     500 non-null float64
# Time on App             500 non-null float64
# Time on Website         500 non-null float64
# Length of Membership    500 non-null float64
# Yearly Amount Spent     500 non-null float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
customers.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
y=customers[ 'Yearly Amount Spent']

# %%
x=customers[['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership', 'Yearly Amount Spent']]

# %%
# !pip install sklearn
import sklearn
# Out:
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1321 sha256=b123aeee79b0bd2a51804715702427a0d847fde7a55b149aabe3eba0ff8ca1bb
#   Stored in directory: C:\Users\Dhiraj kumar\AppData\Local\pip\Cache\wheels\76\03\bb\589d421d27431bcd2c6da284d5f2286c8e3b2ea3cf1594c074
# Successfully built sklearn
# ...

# %%
len(customers)
# Out:
# 500

# %%
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-a35af2a4e137> in <module>
# ----> 1 from sklearn.linear_model import LinearRegression
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\__init__.py in <module>
#      10 # complete documentation.
#      11
# ---> 12 from .base import LinearRegression
#      13
#      14 from .bayes import BayesianRidge, ARDRegression
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in <module>
#      37 from ..utils.validation import check_is_fitted
#      38 from ..exceptions import NotFittedError
# ---> 39 from ..preprocessing.data import normalize as f_normalize
#      40
#      41 # TODO: bayesian_ridge_regression and bayesian_regression_ard
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\__init__.py in <module>
#       4 """
#       5
# ...

# %%
from sklearn.model_selection import train_test_split
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-73edc048c06b> in <module>
# ----> 1 from sklearn.model_selection import train_test_split
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\__init__.py in <module>
#      17 from ._split import check_cv
#      18
# ---> 19 from ._validation import cross_val_score
#      20 from ._validation import cross_val_predict
#      21 from ._validation import cross_validate
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_validation.py in <module>
#      25 from ..utils.metaestimators import _safe_split
#      26 from ..utils._joblib import Parallel, delayed
# ---> 27 from ..metrics.scorer import check_scoring, _check_multimetric_scoring
#      28 from ..exceptions import FitFailedWarning
#      29 from ._split import check_cv
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\__init__.py in <module>
# ...

# %%
train,test=train_test_split(customers,test_size=0.25,random_state=101)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-d3428e51ec14> in <module>
# ----> 1 train,test=train_test_split(customers,test_size=0.25,random_state=101)
#
# NameError: name 'train_test_split' is not defined

# %%
x_train,x_test,y_train,ytest=train_test_split(x,y,test_size=0.3,random_state=101)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-851989ab1970> in <module>
# ----> 1 x_train,x_test,y_train,ytest=train_test_split(x,y,test_size=0.3,random_state=101)
#
# NameError: name 'train_test_split' is not defined

# %% [markdown]
# ### Training the model

# %%
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-a35af2a4e137> in <module>
# ----> 1 from sklearn.linear_model import LinearRegression
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\__init__.py in <module>
#      10 # complete documentation.
#      11
# ---> 12 from .base import LinearRegression
#      13
#      14 from .bayes import BayesianRidge, ARDRegression
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in <module>
#      37 from ..utils.validation import check_is_fitted
#      38 from ..exceptions import NotFittedError
# ---> 39 from ..preprocessing.data import normalize as f_normalize
#      40
#      41 # TODO: bayesian_ridge_regression and bayesian_regression_ard
#
# ~\Anaconda3\lib\site-packages\sklearn\preprocessing\__init__.py in <module>
#       4 """
#       5
# ...

# %%
lm=LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-157207c3f54b> in <module>
# ----> 1 lm=LinearRegression()
#
# NameError: name 'LinearRegression' is not defined

# %%
lm.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-dd304f997297> in <module>
# ----> 1 lm.fit(x_train,y_train)
#
# NameError: name 'lm' is not defined

# %%
predictions =lm.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-d48622f655b8> in <module>
# ----> 1 predictions =lm.predict(x_test)
#
# NameError: name 'lm' is not defined
